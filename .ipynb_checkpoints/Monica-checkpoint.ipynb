# %% [markdown]
# ## 0.1  Final Project Submission
#
# Please fill out:
#
#
# Student name: Monica Haderthauer and Henry Costello
#
# Student pace: full time
#
# Scheduled project review date/time: Friday, 4/22
#
# Instructor name: Praveen Gowtham

# %% [markdown]
# ## Import

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn import tree
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
pd.set_option('display.max_columns', 500)

# %%
df = pd.read_csv('WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    EnvironmentSatisfaction  Gender  HourlyRate  JobInvolvement  JobLevel  \
# 0                        2  Female          94               3         2
# 1                        3    Male          61               2         2
# 2                        4    Male          92               2         1
# 3                        4  Female          56               3         1
# 4                        1    Male          40               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single           5993
# 1     Research Scientist                2       Married           5130
# 2  Laboratory Technician                3        Single           2090
# 3     Research Scientist                3       Married           2909
# 4  Laboratory Technician                2       Married           3468
#
#    MonthlyRate  NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0        19479                   8      Y      Yes                 11
# 1        24907                   1      Y       No                 23
# 2         2396                   6      Y      Yes                 15
# 3        23159                   1      Y      Yes                 11
# 4        16632                   9      Y       No                 12
#
#    PerformanceRating  RelationshipSatisfaction  StandardHours  \
# 0                  3                         1             80
# 1                  4                         4             80
# 2                  3                         2             80
# 3                  3                         3             80
# 4                  3                         4             80
#
#    StockOptionLevel  TotalWorkingYears  TrainingTimesLastYear  \
# 0                 0                  8                      0
# 1                 1                 10                      3
# 2                 0                  7                      3
# 3                 0                  8                      3
# 4                 1                  6                      3
#
#    WorkLifeBalance  YearsAtCompany  YearsInCurrentRole  \
# 0                1               6                   4
# 1                3              10                   7
# 2                3               0                   0
# 3                3               8                   7
# 4                3               2                   2
#
#    YearsSinceLastPromotion  YearsWithCurrManager
# 0                        0                     5
# 1                        1                     7
# 2                        0                     0
# 3                        3                     0
# 4                        2                     2

# %% [markdown]
# ## Column Values

# %%
print(df.apply(lambda col: col.unique()))
# Out:
# Age                         [41, 49, 37, 33, 27, 32, 59, 30, 38, 36, 35, 2...
# Attrition                                                           [Yes, No]
# BusinessTravel                 [Travel_Rarely, Travel_Frequently, Non-Travel]
# DailyRate                   [1102, 279, 1373, 1392, 591, 1005, 1324, 1358,...
# Department                   [Sales, Research & Development, Human Resources]
# DistanceFromHome            [1, 8, 2, 3, 24, 23, 27, 16, 15, 26, 19, 21, 5...
# Education                                                     [2, 1, 4, 3, 5]
# EducationField              [Life Sciences, Other, Medical, Marketing, Tec...
# EmployeeCount                                                             [1]
# EmployeeNumber              [1, 2, 4, 5, 7, 8, 10, 11, 12, 13, 14, 15, 16,...
# EnvironmentSatisfaction                                          [2, 3, 4, 1]
# Gender                                                         [Female, Male]
# HourlyRate                  [94, 61, 92, 56, 40, 79, 81, 67, 44, 84, 49, 3...
# JobInvolvement                                                   [3, 2, 4, 1]
# JobLevel                                                      [2, 1, 3, 4, 5]
# JobRole                     [Sales Executive, Research Scientist, Laborato...
# JobSatisfaction                                                  [4, 2, 3, 1]
# MaritalStatus                                     [Single, Married, Divorced]
# MonthlyIncome               [5993, 5130, 2090, 2909, 3468, 3068, 2670, 269...
# MonthlyRate                 [19479, 24907, 2396, 23159, 16632, 11864, 9964...
# NumCompaniesWorked                             [8, 1, 6, 9, 0, 4, 5, 2, 7, 3]
# Over18                                                                    [Y]
# OverTime                                                            [Yes, No]
# PercentSalaryHike           [11, 23, 15, 12, 13, 20, 22, 21, 17, 14, 16, 1...
# PerformanceRating                                                      [3, 4]
# RelationshipSatisfaction                                         [1, 4, 2, 3]
# StandardHours                                                            [80]
# StockOptionLevel                                                 [0, 1, 3, 2]
# TotalWorkingYears           [8, 10, 7, 6, 12, 1, 17, 5, 3, 31, 13, 0, 26, ...
# TrainingTimesLastYear                                   [0, 3, 2, 5, 1, 4, 6]
# WorkLifeBalance                                                  [1, 3, 2, 4]
# YearsAtCompany              [6, 10, 0, 8, 2, 7, 1, 9, 5, 4, 25, 3, 12, 14,...
# YearsInCurrentRole          [4, 7, 0, 2, 5, 9, 8, 3, 6, 13, 1, 15, 14, 16,...
# YearsSinceLastPromotion     [0, 1, 3, 2, 7, 4, 8, 6, 5, 15, 9, 13, 12, 10,...
# YearsWithCurrManager        [5, 7, 0, 2, 6, 8, 3, 11, 17, 1, 4, 12, 9, 10,...
# dtype: object

# %%
for col in df:
    print(df[col].unique())
    
#printing to see each value
# Out:
# [41 49 37 33 27 32 59 30 38 36 35 29 31 34 28 22 53 24 21 42 44 46 39 43
#  50 26 48 55 45 56 23 51 40 54 58 20 25 19 57 52 47 18 60]
# ['Yes' 'No']
# ['Travel_Rarely' 'Travel_Frequently' 'Non-Travel']
# [1102  279 1373 1392  591 1005 1324 1358  216 1299  809  153  670 1346
#   103 1389  334 1123 1219  371  673 1218  419  391  699 1282 1125  691
#   477  705  924 1459  125  895  813 1273  869  890  852 1141  464 1240
#  1357  994  721 1360 1065  408 1211 1229  626 1434 1488 1097 1443  515
#   853 1142  655 1115  427  653  989 1435 1223  836 1195 1339  664  318
#  1225 1328 1082  548  132  746  776  193  397  945 1214  111  573 1153
#  1400  541  432  288  669  530  632 1334  638 1093 1217 1353  120  682
#   489  807  827  871  665 1040 1420  240 1280  534 1456  658  142 1127
#  1031 1189 1354 1467  922  394 1312  750  441  684  249  841  147  528
#   594  470  957  542  802 1355 1150 1329  959 1033 1316  364  438  689
#   201 1427  857  933 1181 1395  662 1436  194  967 1496 1169 1145  630
#   303 1256  440 1450 1452  465  702 1157  602 1480 1268  713  134  526
#  1380  140  629 1356  328 1084  931  692 1069  313  894  556 1344  290
#   138  926 1261  472 1002  878  905 1180  121 1136  635 1151  644 1045
#   829 1242 1469  896  992 1052 1147 1396  663  119  979  319 1413  944
#  1323  532  818  854 1034  771 1401 1431  976 1411 1300  252 1327  832
#  1017 1199  504  505  916 1247  685  269 1416  833  307 1311  128  488
#   529 1210 1463  675 1385 1403  452  666 1158  228  996  728 1315  322
#  1479  797 1070  442  496 1372  920  688 1449 1117  636  506  444  950
#   889  555  230 1232  566 1302  812 1476  218 1132 1105  906  849  390
#   106 1249  192  553  117  185 1091  723 1220  588 1377 1018 1275  798
#   672 1162  508 1482  559  210  928 1001  549 1124  738  570 1130 1192
#   343  144 1296 1309  483  810  544 1062 1319  641 1332  756  845  593
#  1171  350  921 1144  143 1046  575  156 1283  755  304 1178  329 1362
#  1371  202  253  164 1107  759 1305  982  821 1381  480 1473  891 1063
#   645 1490  317  422 1485 1368 1448  296 1398 1349  986 1099 1116 1499
#   983 1009 1303 1274 1277  587  413 1276  988 1474  163  267  619  302
#   443  828  561  426  232 1306 1094  509  775  195  258  471  799  956
#   535 1495  446 1245  703  823 1246  622 1287  448  254 1365  538  525
#   558  782  362 1236 1112  204 1343  604 1216  646  160  238 1397  306
#   991  482 1176  913 1076  727  885  243  806  817 1410 1207 1442  693
#   929  562  608  580  970 1179  294  314  316  654  168  381  217  501
#   650  141  804  975 1090  346  430  268  167  621  527  883  954  310
#   719  725  715  657 1146  182  376  571  384  791 1111 1243 1092 1325
#   805  213  118  676 1252  286 1258  932 1041  859  720  946 1184  436
#   589  760  887 1318  625  180  586 1012  661  930  342 1230 1271 1278
#   607  130  300  583 1418 1269  379  395 1265 1222  341  868 1231  102
#   881 1383 1075  374 1086  781  177  500 1425 1454  617 1085  995 1122
#   618  546  462 1198 1272  154 1137 1188  188 1333  867  263  938  129
#   616  498 1404 1053  289 1376  231  152  882  903 1379  335  722  461
#   974 1126  840 1134  248  955  939 1391 1206  287 1441  109 1066  277
#   466 1055  265  135  247 1035  266  145 1038 1234 1109 1089  788  124
#   660 1186 1464  796  415  769 1003 1366  330 1492 1204  309 1330  469
#   697 1262 1050  770  406  203 1308  984  439  793 1451 1182  174  490
#   718  433  773  603  874  367  199  481  647 1384  902  819  862 1457
#   977  942 1402 1421 1361  917  200  150  179  696  116  363  107 1465
#   458 1212 1103  966 1010  326 1098  969 1167  694 1320  536  373  599
#   251  131  237 1429  648  735  531  429  968  879  640  412  848  360
#  1138  325 1322  299 1030  634  524  256 1060  935  495  282  206  943
#   523  507  601  855 1291 1405 1369  999 1202  285  404  736 1498 1200
#  1439  499  205  683 1462  949  652  332 1475  337  971 1174  667  560
#   172  383 1255  359  401  377  592 1445 1221  866  981  447 1326  748
#   990  405  115  790  830 1193 1423  467  271  410 1083  516  224  136
#  1029  333 1440  674 1342  898  824  492  598  740  888 1288  104 1108
#   479 1351  474  437  884 1370  264 1059  563  457 1313  241 1015  336
#  1387  170  208  671  711  737 1470  365  763  567  486  772  301  311
#   584  880  392  148  708 1259  786  370  678  146  581  918 1238  585
#   741  552  369  717  543  964  792  611  176  897  600 1054  428  181
#   211 1079  590  305  953  478 1375  244  511 1294  196  734 1239 1253
#  1128 1336  234  766  261 1194  431  572 1422 1297  574  355  207  706
#   280  726  414  352 1224  459 1254 1131  835 1172 1266  783  219 1213
#  1096 1251 1394  605 1064 1337  937  157  754 1168  155 1444  189  911
#  1321 1154  557  642  801  161 1382 1037  105  582  704  345 1120 1378
#   468  613 1023  628]
# ['Sales' 'Research & Development' 'Human Resources']
# [ 1  8  2  3 24 23 27 16 15 26 19 21  5 11  9  7  6 10  4 25 12 18 29 22
#  14 20 28 17 13]
# [2 1 4 3 5]
# ['Life Sciences' 'Other' 'Medical' 'Marketing' 'Technical Degree'
#  'Human Resources']
# [1]
# [   1    2    4 ... 2064 2065 2068]
# [2 3 4 1]
# ['Female' 'Male']
# [ 94  61  92  56  40  79  81  67  44  84  49  31  93  50  51  80  96  78
#   45  82  53  83  58  72  48  42  41  86  97  75  33  37  73  98  36  47
#   71  30  43  99  59  95  57  76  87  66  55  32  52  70  62  64  63  60
#  100  46  39  77  35  91  54  34  90  65  88  85  89  68  69  74  38]
# [3 2 4 1]
# [2 1 3 4 5]
# ['Sales Executive' 'Research Scientist' 'Laboratory Technician'
#  'Manufacturing Director' 'Healthcare Representative' 'Manager'
#  'Sales Representative' 'Research Director' 'Human Resources']
# [4 2 3 1]
# ['Single' 'Married' 'Divorced']
# [5993 5130 2090 ... 9991 5390 4404]
# [19479 24907  2396 ...  5174 13243 10228]
# [8 1 6 9 0 4 5 2 7 3]
# ['Y']
# ['Yes' 'No']
# [11 23 15 12 13 20 22 21 17 14 16 18 19 24 25]
# [3 4]
# [1 4 2 3]
# [80]
# [0 1 3 2]
# [ 8 10  7  6 12  1 17  5  3 31 13  0 26 24 22  9 19  2 23 14 15  4 29 28
#  21 25 20 11 16 37 38 30 40 18 36 34 32 33 35 27]
# [0 3 2 5 1 4 6]
# [1 3 2 4]
# [ 6 10  0  8  2  7  1  9  5  4 25  3 12 14 22 15 27 21 17 11 13 37 16 20
#  40 24 33 19 36 18 29 31 32 34 26 30 23]
# [ 4  7  0  2  5  9  8  3  6 13  1 15 14 16 11 10 12 18 17]
# [ 0  1  3  2  7  4  8  6  5 15  9 13 12 10 11 14]
# [ 5  7  0  2  6  8  3 11 17  1  4 12  9 10 15 13 16 14]

# %%
numeric_cols = df.select_dtypes(include=np.number)

for column in numeric_cols:
    plt.figure()
    df.boxplot([column])
# Out:
# <ipython-input-7-dcaacaf39c84>:4: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %%
df['AnnualIncome'] = df['MonthlyIncome'] * 12

# %%
plt.figure(figsize = (15,8))

sns.set_theme()

ax = sns.boxplot(x='AnnualIncome', y='Gender', data=df);

# title
# labels


ax.xaxis.set_major_formatter('${x:,.0f}')

# %%
data = [df.groupby('Attrition')['Attrition'].count()[0], df.groupby('Attrition')['Attrition'].count()[1]]
labels=['No', 'Yes']

#define Seaborn color palette to use

#create pie chart
plt.pie(data, labels = labels, autopct='%.1f%%', shadow=True, explode=[0.025, 0.1],radius = 2)


plt.title("Did they stay or did they go?\n" + "Attrition Rate at IBM", bbox={'facecolor':'0.9', 'pad':5})


plt.show()

# %%
plt.figure(figsize = (10,8))


sns.countplot(x='PercentSalaryHike',palette = "Set2", hue='Attrition', data=df);

# %%
plt.figure(figsize = (12,8))

sns.countplot(x='Age', hue='Attrition', data=df);

# %%
#deleting outliers
df = df[df['MonthlyIncome'] < 12000]
df = df[df['YearsSinceLastPromotion'] < 6]
df = df[df['YearsWithCurrManager'] < 15]
df = df[df['TotalWorkingYears'] < 21]
df = df[df['TrainingTimesLastYear'] < 5]
df = df[df['YearsAtCompany'] < 17]
df = df[df['YearsInCurrentRole'] < 15]
df = df[df['JobLevel'] < 3.5]


df['YearsWithCurrManager'].value_counts()
# Out:
# 2     275
# 0     197
# 7     116
# 3     112
# 4      68
# 1      51
# 8      41
# 9      28
# 5      19
# 6      11
# 10      7
# 12      6
# 11      6
# 13      1
# Name: YearsWithCurrManager, dtype: int64

# %%
df = df.drop(columns= ['DailyRate', 'EmployeeNumber', 'HourlyRate', 'MonthlyRate',
                              'PerformanceRating'])
numeric_cols = df.select_dtypes(include=np.number)

# %%
for column in numeric_cols:
    plt.figure()
    df.boxplot([column])
# Out:
# <ipython-input-15-6763f38c2c78>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure()

# %%
df['Attrition'] = df['Attrition'].apply(lambda x: 0 if x =='No' else 1)

# %%
df.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   41          1      Travel_Rarely                   Sales
# 1   49          0  Travel_Frequently  Research & Development
# 2   37          1      Travel_Rarely  Research & Development
# 3   33          0  Travel_Frequently  Research & Development
# 4   27          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  \
# 0                 1          2  Life Sciences              1
# 1                 8          1  Life Sciences              1
# 2                 2          2          Other              1
# 3                 3          4  Life Sciences              1
# 4                 2          1        Medical              1
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  \
# 0                        2  Female               3         2
# 1                        3    Male               2         2
# 2                        4    Male               2         1
# 3                        4  Female               3         1
# 4                        1    Male               3         1
#
#                  JobRole  JobSatisfaction MaritalStatus  MonthlyIncome  \
# 0        Sales Executive                4        Single           5993
# 1     Research Scientist                2       Married           5130
# 2  Laboratory Technician                3        Single           2090
# 3     Research Scientist                3       Married           2909
# 4  Laboratory Technician                2       Married           3468
#
#    NumCompaniesWorked Over18 OverTime  PercentSalaryHike  \
# 0                   8      Y      Yes                 11
# 1                   1      Y       No                 23
# 2                   6      Y      Yes                 15
# 3                   1      Y      Yes                 11
# 4                   9      Y       No                 12
#
#    RelationshipSatisfaction  StandardHours  StockOptionLevel  \
# 0                         1             80                 0
# 1                         4             80                 1
# 2                         2             80                 0
# 3                         3             80                 0
# 4                         4             80                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
#    AnnualIncome
# 0         71916
# 1         61560
# 2         25080
# 3         34908
# 4         41616

# %%
df['Attrition'].value_counts()
# Out:
# 0    763
# 1    175
# Name: Attrition, dtype: int64

# %%
df['EmployeeCount'].value_counts()
# Out:
# 1    938
# Name: EmployeeCount, dtype: int64

# %%
df['StandardHours'].value_counts()
# Out:
# 80    938
# Name: StandardHours, dtype: int64

# %%
df['Over18'].value_counts()
# Out:
# Y    938
# Name: Over18, dtype: int64

# %%
df = df.drop(columns=['EmployeeCount', 'StandardHours', 'Over18'])
#dropping these columns because they each only contain one unique value and will not help analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 938 entries, 0 to 1469
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       938 non-null    int64
#  1   Attrition                 938 non-null    int64
#  2   BusinessTravel            938 non-null    object
#  3   Department                938 non-null    object
#  4   DistanceFromHome          938 non-null    int64
#  5   Education                 938 non-null    int64
#  6   EducationField            938 non-null    object
#  7   EnvironmentSatisfaction   938 non-null    int64
#  8   Gender                    938 non-null    object
#  9   JobInvolvement            938 non-null    int64
#  10  JobLevel                  938 non-null    int64
#  11  JobRole                   938 non-null    object
#  12  JobSatisfaction           938 non-null    int64
#  13  MaritalStatus             938 non-null    object
#  14  MonthlyIncome             938 non-null    int64
#  15  NumCompaniesWorked        938 non-null    int64
#  16  OverTime                  938 non-null    object
#  17  PercentSalaryHike         938 non-null    int64
#  18  RelationshipSatisfaction  938 non-null    int64
#  19  StockOptionLevel          938 non-null    int64
#  20  TotalWorkingYears         938 non-null    int64
#  21  TrainingTimesLastYear     938 non-null    int64
#  22  WorkLifeBalance           938 non-null    int64
#  23  YearsAtCompany            938 non-null    int64
#  24  YearsInCurrentRole        938 non-null    int64
#  25  YearsSinceLastPromotion   938 non-null    int64
#  26  YearsWithCurrManager      938 non-null    int64
#  27  AnnualIncome              938 non-null    int64
# dtypes: int64(21), object(7)
# memory usage: 212.5+ KB

# %%
df.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EnvironmentSatisfaction     0
# Gender                      0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# AnnualIncome                0
# dtype: int64

# %% [markdown]
# ## Correlation

# %%
df.corr()['Attrition'].sort_values(ascending=False)
# Out:
# Attrition                   1.000000
# DistanceFromHome            0.100958
# NumCompaniesWorked          0.042538
# PercentSalaryHike          -0.002079
# TrainingTimesLastYear      -0.006281
# Education                  -0.032666
# WorkLifeBalance            -0.062773
# RelationshipSatisfaction   -0.073439
# YearsSinceLastPromotion    -0.079108
# JobSatisfaction            -0.125723
# JobInvolvement             -0.137475
# StockOptionLevel           -0.138060
# EnvironmentSatisfaction    -0.149480
# Age                        -0.152731
# AnnualIncome               -0.159990
# MonthlyIncome              -0.159990
# JobLevel                   -0.165300
# YearsWithCurrManager       -0.200570
# YearsInCurrentRole         -0.204840
# TotalWorkingYears          -0.206670
# YearsAtCompany             -0.226950
# Name: Attrition, dtype: float64

# %%
df.plot.scatter('DistanceFromHome','Attrition');
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ## Encoding

# %%
numeric_cols = df.select_dtypes(include=np.number)
categorical_cols = df.select_dtypes(include=['object'])

# %%
encodedcats = pd.get_dummies(categorical_cols)
encodecats = pd.concat([encodedcats, numeric_cols], axis = 1)
encodecats.corr()['Attrition'].sort_values(ascending=False)
# Out:
# Attrition                            1.000000
# OverTime_Yes                         0.249267
# MaritalStatus_Single                 0.177317
# JobRole_Sales Representative         0.166000
# BusinessTravel_Travel_Frequently     0.127994
# JobRole_Laboratory Technician        0.100993
# DistanceFromHome                     0.100958
# EducationField_Technical Degree      0.080550
# Department_Sales                     0.063260
# EducationField_Human Resources       0.057013
# NumCompaniesWorked                   0.042538
# EducationField_Marketing             0.039830
# JobRole_Human Resources              0.030641
# Department_Human Resources           0.030641
# Gender_Male                          0.019709
# PercentSalaryHike                   -0.002079
# TrainingTimesLastYear               -0.006281
# Gender_Female                       -0.019709
# EducationField_Other                -0.024375
# JobRole_Manager                     -0.027128
# JobRole_Sales Executive             -0.032121
# EducationField_Medical              -0.032477
# Education                           -0.032666
# JobRole_Research Director           -0.044418
# JobRole_Research Scientist          -0.046198
# EducationField_Life Sciences        -0.049206
# BusinessTravel_Travel_Rarely        -0.053566
# WorkLifeBalance                     -0.062773
# MaritalStatus_Divorced              -0.066733
# RelationshipSatisfaction            -0.073439
# Department_Research & Development   -0.074739
# YearsSinceLastPromotion             -0.079108
# JobRole_Healthcare Representative   -0.083402
# BusinessTravel_Non-Travel           -0.084349
# JobRole_Manufacturing Director      -0.100269
# MaritalStatus_Married               -0.113543
# JobSatisfaction                     -0.125723
# JobInvolvement                      -0.137475
# StockOptionLevel                    -0.138060
# EnvironmentSatisfaction             -0.149480
# Age                                 -0.152731
# AnnualIncome                        -0.159990
# MonthlyIncome                       -0.159990
# JobLevel                            -0.165300
# YearsWithCurrManager                -0.200570
# YearsInCurrentRole                  -0.204840
# TotalWorkingYears                   -0.206670
# YearsAtCompany                      -0.226950
# OverTime_No                         -0.249267
# Name: Attrition, dtype: float64

# %%
df.select_dtypes(include = np.number, exclude = object).corr()
# Out:
#                                Age  Attrition  DistanceFromHome  Education  \
# Age                       1.000000  -0.152731          0.007123   0.241917
# Attrition                -0.152731   1.000000          0.100958  -0.032666
# DistanceFromHome          0.007123   0.100958          1.000000  -0.011548
# Education                 0.241917  -0.032666         -0.011548   1.000000
# EnvironmentSatisfaction   0.011192  -0.149480         -0.012446  -0.025758
# JobInvolvement            0.041363  -0.137475         -0.011216   0.044254
# JobLevel                  0.257422  -0.165300          0.084110   0.117126
# JobSatisfaction           0.013614  -0.125723          0.006080  -0.019498
# MonthlyIncome             0.237086  -0.159990          0.059777   0.113193
# NumCompaniesWorked        0.295564   0.042538         -0.011390   0.142724
# PercentSalaryHike         0.034404  -0.002079          0.009512  -0.003333
# RelationshipSatisfaction  0.039816  -0.073439         -0.010845   0.008797
# StockOptionLevel          0.071817  -0.138060          0.066140   0.048764
# TotalWorkingYears         0.519703  -0.206670          0.045074   0.184877
# TrainingTimesLastYear     0.043746  -0.006281         -0.026157   0.029593
# WorkLifeBalance          -0.007228  -0.062773         -0.044153   0.041402
# YearsAtCompany            0.113158  -0.226950          0.021656   0.075930
# YearsInCurrentRole        0.095494  -0.204840          0.027669   0.083922
# YearsSinceLastPromotion   0.059865  -0.079108         -0.015766   0.015406
# YearsWithCurrManager      0.097699  -0.200570          0.010063   0.046545
# AnnualIncome              0.237086  -0.159990          0.059777   0.113193
#
#                           EnvironmentSatisfaction  JobInvolvement  JobLevel  \
# Age                                      0.011192        0.041363  0.257422
# Attrition                               -0.149480       -0.137475 -0.165300
# DistanceFromHome                        -0.012446       -0.011216  0.084110
# Education                               -0.025758        0.044254  0.117126
# EnvironmentSatisfaction                  1.000000        0.019876  0.014378
# JobInvolvement                           0.019876        1.000000 -0.004403
# JobLevel                                 0.014378       -0.004403  1.000000
# JobSatisfaction                         -0.031997       -0.008958 -0.001587
# MonthlyIncome                           -0.009230       -0.025667  0.866081
# NumCompaniesWorked                       0.005492        0.030844  0.101258
# PercentSalaryHike                       -0.019040       -0.004147 -0.029763
# RelationshipSatisfaction                 0.029313        0.028523 -0.003611
# StockOptionLevel                         0.047875       -0.009615  0.037584
# TotalWorkingYears                       -0.027430        0.019911  0.526005
# TrainingTimesLastYear                    0.017898        0.002215 -0.013759
# WorkLifeBalance                          0.008006        0.000840  0.032458
# YearsAtCompany                           0.019007        0.036442  0.408271
# YearsInCurrentRole                       0.035613        0.014357  0.358830
# YearsSinceLastPromotion                  0.044996       -0.007634  0.105858
# YearsWithCurrManager                     0.005386        0.049172  0.368542
# AnnualIncome                            -0.009230       -0.025667  0.866081
#
#                           JobSatisfaction  MonthlyIncome  NumCompaniesWorked  \
# Age                              0.013614       0.237086            0.295564
# Attrition                       -0.125723      -0.159990            0.042538
# DistanceFromHome                 0.006080       0.059777           -0.011390
# Education                       -0.019498       0.113193            0.142724
# EnvironmentSatisfaction         -0.031997      -0.009230            0.005492
# JobInvolvement                  -0.008958      -0.025667            0.030844
# JobLevel                        -0.001587       0.866081            0.101258
# JobSatisfaction                  1.000000      -0.001988           -0.039002
# MonthlyIncome                   -0.001988       1.000000            0.115638
# NumCompaniesWorked              -0.039002       0.115638            1.000000
# PercentSalaryHike                0.004850      -0.019945           -0.006739
# RelationshipSatisfaction         0.039348       0.000198            0.015916
# StockOptionLevel                 0.006327       0.028550            0.046688
# TotalWorkingYears               -0.017531       0.497600            0.306875
# TrainingTimesLastYear           -0.047618      -0.043121           -0.000230
# WorkLifeBalance                 -0.035318       0.016142            0.012347
# YearsAtCompany                   0.054643       0.380003           -0.151128
# YearsInCurrentRole               0.033321       0.335616           -0.111169
# YearsSinceLastPromotion          0.044342       0.109425           -0.034462
# YearsWithCurrManager             0.022873       0.341767           -0.105262
# AnnualIncome                    -0.001988       1.000000            0.115638
#
#                           PercentSalaryHike  RelationshipSatisfaction  \
# Age                                0.034404                  0.039816
# Attrition                         -0.002079                 -0.073439
# DistanceFromHome                   0.009512                 -0.010845
# Education                         -0.003333                  0.008797
# EnvironmentSatisfaction           -0.019040                  0.029313
# JobInvolvement                    -0.004147                  0.028523
# JobLevel                          -0.029763                 -0.003611
# JobSatisfaction                    0.004850                  0.039348
# MonthlyIncome                     -0.019945                  0.000198
# NumCompaniesWorked                -0.006739                  0.015916
# PercentSalaryHike                  1.000000                 -0.031499
# RelationshipSatisfaction          -0.031499                  1.000000
# StockOptionLevel                   0.022075                 -0.038626
# TotalWorkingYears                  0.013451                 -0.017816
# TrainingTimesLastYear              0.018321                  0.012517
# WorkLifeBalance                   -0.044894                  0.044393
# YearsAtCompany                    -0.009198                 -0.013002
# YearsInCurrentRole                -0.001009                 -0.023462
# YearsSinceLastPromotion            0.005628                  0.030753
# YearsWithCurrManager               0.008995                  0.007345
# AnnualIncome                      -0.019945                  0.000198
#
#                           StockOptionLevel  TotalWorkingYears  \
# Age                               0.071817           0.519703
# Attrition                        -0.138060          -0.206670
# DistanceFromHome                  0.066140           0.045074
# Education                         0.048764           0.184877
# EnvironmentSatisfaction           0.047875          -0.027430
# JobInvolvement                   -0.009615           0.019911
# JobLevel                          0.037584           0.526005
# JobSatisfaction                   0.006327          -0.017531
# MonthlyIncome                     0.028550           0.497600
# NumCompaniesWorked                0.046688           0.306875
# PercentSalaryHike                 0.022075           0.013451
# RelationshipSatisfaction         -0.038626          -0.017816
# StockOptionLevel                  1.000000           0.055612
# TotalWorkingYears                 0.055612           1.000000
# TrainingTimesLastYear             0.021290           0.032774
# WorkLifeBalance                   0.035726           0.009165
# YearsAtCompany                    0.046184           0.495345
# YearsInCurrentRole                0.042694           0.427591
# YearsSinceLastPromotion           0.010122           0.201645
# YearsWithCurrManager              0.030692           0.439762
# AnnualIncome                      0.028550           0.497600
#
#                           TrainingTimesLastYear  WorkLifeBalance  \
# Age                                    0.043746        -0.007228
# Attrition                             -0.006281        -0.062773
# DistanceFromHome                      -0.026157        -0.044153
# Education                              0.029593         0.041402
# EnvironmentSatisfaction                0.017898         0.008006
# JobInvolvement                         0.002215         0.000840
# JobLevel                              -0.013759         0.032458
# JobSatisfaction                       -0.047618        -0.035318
# MonthlyIncome                         -0.043121         0.016142
# NumCompaniesWorked                    -0.000230         0.012347
# PercentSalaryHike                      0.018321        -0.044894
# RelationshipSatisfaction               0.012517         0.044393
# StockOptionLevel                       0.021290         0.035726
# TotalWorkingYears                      0.032774         0.009165
# TrainingTimesLastYear                  1.000000         0.046999
# WorkLifeBalance                        0.046999         1.000000
# YearsAtCompany                         0.019906         0.023951
# YearsInCurrentRole                     0.018357         0.031353
# YearsSinceLastPromotion                0.020602         0.042058
# YearsWithCurrManager                   0.003922         0.037764
# AnnualIncome                          -0.043121         0.016142
#
#                           YearsAtCompany  YearsInCurrentRole  \
# Age                             0.113158            0.095494
# Attrition                      -0.226950           -0.204840
# DistanceFromHome                0.021656            0.027669
# Education                       0.075930            0.083922
# EnvironmentSatisfaction         0.019007            0.035613
# JobInvolvement                  0.036442            0.014357
# JobLevel                        0.408271            0.358830
# JobSatisfaction                 0.054643            0.033321
# MonthlyIncome                   0.380003            0.335616
# NumCompaniesWorked             -0.151128           -0.111169
# PercentSalaryHike              -0.009198           -0.001009
# RelationshipSatisfaction       -0.013002           -0.023462
# StockOptionLevel                0.046184            0.042694
# TotalWorkingYears               0.495345            0.427591
# TrainingTimesLastYear           0.019906            0.018357
# WorkLifeBalance                 0.023951            0.031353
# YearsAtCompany                  1.000000            0.857825
# YearsInCurrentRole              0.857825            1.000000
# YearsSinceLastPromotion         0.395451            0.416740
# YearsWithCurrManager            0.846897            0.739570
# AnnualIncome                    0.380003            0.335616
#
#                           YearsSinceLastPromotion  YearsWithCurrManager  \
# Age                                      0.059865              0.097699
# Attrition                               -0.079108             -0.200570
# DistanceFromHome                        -0.015766              0.010063
# Education                                0.015406              0.046545
# EnvironmentSatisfaction                  0.044996              0.005386
# JobInvolvement                          -0.007634              0.049172
# JobLevel                                 0.105858              0.368542
# JobSatisfaction                          0.044342              0.022873
# MonthlyIncome                            0.109425              0.341767
# NumCompaniesWorked                      -0.034462             -0.105262
# PercentSalaryHike                        0.005628              0.008995
# RelationshipSatisfaction                 0.030753              0.007345
# StockOptionLevel                         0.010122              0.030692
# TotalWorkingYears                        0.201645              0.439762
# TrainingTimesLastYear                    0.020602              0.003922
# WorkLifeBalance                          0.042058              0.037764
# YearsAtCompany                           0.395451              0.846897
# YearsInCurrentRole                       0.416740              0.739570
# YearsSinceLastPromotion                  1.000000              0.349210
# YearsWithCurrManager                     0.349210              1.000000
# AnnualIncome                             0.109425              0.341767
#
#                           AnnualIncome
# Age                           0.237086
# Attrition                    -0.159990
# DistanceFromHome              0.059777
# Education                     0.113193
# EnvironmentSatisfaction      -0.009230
# JobInvolvement               -0.025667
# JobLevel                      0.866081
# JobSatisfaction              -0.001988
# MonthlyIncome                 1.000000
# NumCompaniesWorked            0.115638
# PercentSalaryHike            -0.019945
# RelationshipSatisfaction      0.000198
# StockOptionLevel              0.028550
# TotalWorkingYears             0.497600
# TrainingTimesLastYear        -0.043121
# WorkLifeBalance               0.016142
# YearsAtCompany                0.380003
# YearsInCurrentRole            0.335616
# YearsSinceLastPromotion       0.109425
# YearsWithCurrManager          0.341767
# AnnualIncome                  1.000000

# %% [markdown]
# ## Heatmap

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.select_dtypes(include = np.number, exclude = object).corr());

# %%
#high correlation- job level and annual income, years with current manager and years at company

# %%
encodecats.corr()
# Out:
#                                    BusinessTravel_Non-Travel  \
# BusinessTravel_Non-Travel                           1.000000
# BusinessTravel_Travel_Frequently                   -0.167393
# BusinessTravel_Travel_Rarely                       -0.527931
# Department_Human Resources                         -0.013738
# Department_Research & Development                   0.007550
# Department_Sales                                   -0.001398
# EducationField_Human Resources                     -0.005076
# EducationField_Life Sciences                        0.015488
# EducationField_Marketing                           -0.027114
# EducationField_Medical                             -0.026798
# EducationField_Other                               -0.010418
# EducationField_Technical Degree                     0.056075
# Gender_Female                                      -0.072031
# Gender_Male                                         0.072031
# JobRole_Healthcare Representative                   0.023677
# JobRole_Human Resources                            -0.013738
# JobRole_Laboratory Technician                      -0.016135
# JobRole_Manager                                    -0.019458
# JobRole_Manufacturing Director                     -0.017659
# JobRole_Research Director                           0.081338
# JobRole_Research Scientist                          0.004132
# JobRole_Sales Executive                             0.019957
# JobRole_Sales Representative                       -0.031531
# MaritalStatus_Divorced                              0.071232
# MaritalStatus_Married                              -0.013313
# MaritalStatus_Single                               -0.048105
# OverTime_No                                         0.039061
# OverTime_Yes                                       -0.039061
# Age                                                 0.013109
# Attrition                                          -0.084349
# DistanceFromHome                                    0.029057
# Education                                           0.002966
# EnvironmentSatisfaction                            -0.010148
# JobInvolvement                                     -0.023957
# JobLevel                                            0.029963
# JobSatisfaction                                    -0.017816
# MonthlyIncome                                       0.007317
# NumCompaniesWorked                                  0.019725
# PercentSalaryHike                                   0.036800
# RelationshipSatisfaction                           -0.015137
# StockOptionLevel                                    0.057177
# TotalWorkingYears                                  -0.012882
# TrainingTimesLastYear                              -0.065107
# WorkLifeBalance                                     0.026923
# YearsAtCompany                                      0.035719
# YearsInCurrentRole                                  0.052671
# YearsSinceLastPromotion                             0.003974
# YearsWithCurrManager                                0.054813
# AnnualIncome                                        0.007317
#
#                                    BusinessTravel_Travel_Frequently  \
# BusinessTravel_Non-Travel                                 -0.167393
# BusinessTravel_Travel_Frequently                           1.000000
# BusinessTravel_Travel_Rarely                              -0.748932
# Department_Human Resources                                 0.002165
# Department_Research & Development                         -0.018626
# Department_Sales                                           0.018332
# EducationField_Human Resources                             0.036053
# EducationField_Life Sciences                               0.021972
# EducationField_Marketing                                  -0.024641
# EducationField_Medical                                     0.001122
# EducationField_Other                                      -0.015836
# EducationField_Technical Degree                           -0.017521
# Gender_Female                                              0.020386
# Gender_Male                                               -0.020386
# JobRole_Healthcare Representative                         -0.007654
# JobRole_Human Resources                                    0.002165
# JobRole_Laboratory Technician                              0.013297
# JobRole_Manager                                           -0.027603
# JobRole_Manufacturing Director                            -0.002489
# JobRole_Research Director                                 -0.045197
# JobRole_Research Scientist                                -0.015814
# JobRole_Sales Executive                                   -0.013329
# JobRole_Sales Representative                               0.057353
# MaritalStatus_Divorced                                    -0.014090
# MaritalStatus_Married                                     -0.031767
# MaritalStatus_Single                                       0.045618
# OverTime_No                                               -0.012097
# OverTime_Yes                                               0.012097
# Age                                                       -0.009697
# Attrition                                                  0.127994
# DistanceFromHome                                          -0.017952
# Education                                                 -0.033238
# EnvironmentSatisfaction                                   -0.022966
# JobInvolvement                                             0.019236
# JobLevel                                                  -0.013138
# JobSatisfaction                                            0.058166
# MonthlyIncome                                             -0.021922
# NumCompaniesWorked                                        -0.042285
# PercentSalaryHike                                         -0.037363
# RelationshipSatisfaction                                   0.063703
# StockOptionLevel                                          -0.015410
# TotalWorkingYears                                          0.002681
# TrainingTimesLastYear                                      0.038523
# WorkLifeBalance                                            0.025216
# YearsAtCompany                                             0.023824
# YearsInCurrentRole                                         0.028066
# YearsSinceLastPromotion                                    0.013113
# YearsWithCurrManager                                       0.005274
# AnnualIncome                                              -0.021922
#
#                                    BusinessTravel_Travel_Rarely  \
# BusinessTravel_Non-Travel                             -0.527931
# BusinessTravel_Travel_Frequently                      -0.748932
# BusinessTravel_Travel_Rarely                           1.000000
# Department_Human Resources                             0.007368
# Department_Research & Development                      0.010971
# Department_Sales                                      -0.014852
# EducationField_Human Resources                        -0.027646
# EducationField_Life Sciences                          -0.029338
# EducationField_Marketing                               0.039451
# EducationField_Medical                                 0.017045
# EducationField_Other                                   0.020644
# EducationField_Technical Degree                       -0.022597
# Gender_Female                                          0.030853
# Gender_Male                                           -0.030853
# JobRole_Healthcare Representative                     -0.009320
# JobRole_Human Resources                                0.007368
# JobRole_Laboratory Technician                         -0.000609
# JobRole_Manager                                        0.036857
# JobRole_Manufacturing Director                         0.014013
# JobRole_Research Director                             -0.015736
# JobRole_Research Scientist                             0.010845
# JobRole_Sales Executive                               -0.001932
# JobRole_Sales Representative                          -0.028213
# MaritalStatus_Divorced                                -0.035739
# MaritalStatus_Married                                  0.036314
# MaritalStatus_Single                                  -0.006964
# OverTime_No                                           -0.015833
# OverTime_Yes                                           0.015833
# Age                                                   -0.000458
# Attrition                                             -0.053566
# DistanceFromHome                                      -0.004066
# Education                                              0.026639
# EnvironmentSatisfaction                                0.026604
# JobInvolvement                                        -0.000469
# JobLevel                                              -0.008821
# JobSatisfaction                                       -0.038132
# MonthlyIncome                                          0.013967
# NumCompaniesWorked                                     0.023168
# PercentSalaryHike                                      0.007451
# RelationshipSatisfaction                              -0.044703
# StockOptionLevel                                      -0.025156
# TotalWorkingYears                                      0.006349
# TrainingTimesLastYear                                  0.010575
# WorkLifeBalance                                       -0.039818
# YearsAtCompany                                        -0.044532
# YearsInCurrentRole                                    -0.059579
# YearsSinceLastPromotion                               -0.013967
# YearsWithCurrManager                                  -0.041385
# AnnualIncome                                           0.013967
#
#                                    Department_Human Resources  \
# BusinessTravel_Non-Travel                           -0.013738
# BusinessTravel_Travel_Frequently                     0.002165
# BusinessTravel_Travel_Rarely                         0.007368
# Department_Human Resources                           1.000000
# Department_Research & Development                   -0.306806
# Department_Sales                                    -0.150403
# EducationField_Human Resources                       0.666390
# EducationField_Life Sciences                        -0.084161
# EducationField_Marketing                            -0.082344
# EducationField_Medical                              -0.057145
# EducationField_Other                                 0.007456
# EducationField_Technical Degree                     -0.022274
# Gender_Female                                       -0.012377
# Gender_Male                                          0.012377
# JobRole_Healthcare Representative                   -0.067911
# JobRole_Human Resources                              1.000000
# JobRole_Laboratory Technician                       -0.117466
# JobRole_Manager                                     -0.012863
# JobRole_Manufacturing Director                      -0.073981
# JobRole_Research Director                           -0.021062
# JobRole_Research Scientist                          -0.130178
# JobRole_Sales Executive                             -0.123462
# JobRole_Sales Representative                        -0.064489
# MaritalStatus_Divorced                               0.023883
# MaritalStatus_Married                                0.045702
# MaritalStatus_Single                                -0.068776
# OverTime_No                                          0.016631
# OverTime_Yes                                        -0.016631
# Age                                                 -0.000188
# Attrition                                            0.030641
# DistanceFromHome                                    -0.025809
# Education                                            0.014362
# EnvironmentSatisfaction                             -0.025077
# JobInvolvement                                       0.003794
# JobLevel                                            -0.066476
# JobSatisfaction                                     -0.037137
# MonthlyIncome                                       -0.061050
# NumCompaniesWorked                                   0.029458
# PercentSalaryHike                                   -0.016445
# RelationshipSatisfaction                             0.041767
# StockOptionLevel                                    -0.020013
# TotalWorkingYears                                   -0.025749
# TrainingTimesLastYear                               -0.008052
# WorkLifeBalance                                      0.037174
# YearsAtCompany                                      -0.010572
# YearsInCurrentRole                                  -0.033424
# YearsSinceLastPromotion                              0.035750
# YearsWithCurrManager                                -0.014311
# AnnualIncome                                        -0.061050
#
#                                    Department_Research & Development  \
# BusinessTravel_Non-Travel                                   0.007550
# BusinessTravel_Travel_Frequently                           -0.018626
# BusinessTravel_Travel_Rarely                                0.010971
# Department_Human Resources                                 -0.306806
# Department_Research & Development                           1.000000
# Department_Sales                                           -0.894801
# EducationField_Human Resources                             -0.204452
# EducationField_Life Sciences                                0.154203
# EducationField_Marketing                                   -0.489895
# EducationField_Medical                                      0.189898
# EducationField_Other                                        0.048939
# EducationField_Technical Degree                             0.047002
# Gender_Female                                              -0.035776
# Gender_Male                                                 0.035776
# JobRole_Healthcare Representative                           0.221348
# JobRole_Human Resources                                    -0.306806
# JobRole_Laboratory Technician                               0.382868
# JobRole_Manager                                            -0.037043
# JobRole_Manufacturing Director                              0.241133
# JobRole_Research Director                                   0.068649
# JobRole_Research Scientist                                  0.424301
# JobRole_Sales Executive                                    -0.734522
# JobRole_Sales Representative                               -0.383669
# MaritalStatus_Divorced                                      0.017319
# MaritalStatus_Married                                      -0.012382
# MaritalStatus_Single                                       -0.002099
# OverTime_No                                                 0.011308
# OverTime_Yes                                               -0.011308
# Age                                                         0.030403
# Attrition                                                  -0.074739
# DistanceFromHome                                            0.006529
# Education                                                  -0.048230
# EnvironmentSatisfaction                                     0.032885
# JobInvolvement                                              0.038292
# JobLevel                                                   -0.249243
# JobSatisfaction                                             0.008748
# MonthlyIncome                                              -0.203020
# NumCompaniesWorked                                          0.034302
# PercentSalaryHike                                           0.067726
# RelationshipSatisfaction                                   -0.003831
# StockOptionLevel                                           -0.003352
# TotalWorkingYears                                           0.006593
# TrainingTimesLastYear                                      -0.055653
# WorkLifeBalance                                            -0.066419
# YearsAtCompany                                             -0.044423
# YearsInCurrentRole                                         -0.048972
# YearsSinceLastPromotion                                    -0.010453
# YearsWithCurrManager                                       -0.036015
# AnnualIncome                                               -0.203020
#
#                                    Department_Sales  \
# BusinessTravel_Non-Travel                 -0.001398
# BusinessTravel_Travel_Frequently           0.018332
# BusinessTravel_Travel_Rarely              -0.014852
# Department_Human Resources                -0.150403
# Department_Research & Development         -0.894801
# Department_Sales                           1.000000
# EducationField_Human Resources            -0.100227
# EducationField_Life Sciences              -0.120696
# EducationField_Marketing                   0.547491
# EducationField_Medical                    -0.170445
# EducationField_Other                      -0.054331
# EducationField_Technical Degree           -0.038374
# Gender_Female                              0.042967
# Gender_Male                               -0.042967
# JobRole_Healthcare Representative         -0.198063
# JobRole_Human Resources                   -0.150403
# JobRole_Laboratory Technician             -0.342591
# JobRole_Manager                            0.044512
# JobRole_Manufacturing Director            -0.215766
# JobRole_Research Director                 -0.061427
# JobRole_Research Scientist                -0.379665
# JobRole_Sales Executive                    0.820878
# JobRole_Sales Representative               0.428775
# MaritalStatus_Divorced                    -0.029193
# MaritalStatus_Married                     -0.008577
# MaritalStatus_Single                       0.034442
# OverTime_No                               -0.019547
# OverTime_Yes                               0.019547
# Age                                       -0.031492
# Attrition                                  0.063260
# DistanceFromHome                           0.005324
# Education                                  0.043360
# EnvironmentSatisfaction                   -0.022395
# JobInvolvement                            -0.041554
# JobLevel                                   0.290076
# JobSatisfaction                            0.008334
# MonthlyIncome                              0.239519
# NumCompaniesWorked                        -0.049449
# PercentSalaryHike                         -0.062635
# RelationshipSatisfaction                  -0.015613
# StockOptionLevel                           0.012870
# TotalWorkingYears                          0.005231
# TrainingTimesLastYear                      0.061585
# WorkLifeBalance                            0.051553
# YearsAtCompany                             0.051103
# YearsInCurrentRole                         0.066547
# YearsSinceLastPromotion                   -0.005912
# YearsWithCurrManager                       0.044123
# AnnualIncome                               0.239519
#
#                                    EducationField_Human Resources  \
# BusinessTravel_Non-Travel                               -0.005076
# BusinessTravel_Travel_Frequently                         0.036053
# BusinessTravel_Travel_Rarely                            -0.027646
# Department_Human Resources                               0.666390
# Department_Research & Development                       -0.204452
# Department_Sales                                        -0.100227
# EducationField_Human Resources                           1.000000
# EducationField_Life Sciences                            -0.129352
# EducationField_Marketing                                -0.054873
# EducationField_Medical                                  -0.096210
# EducationField_Other                                    -0.037402
# EducationField_Technical Degree                         -0.048692
# Gender_Female                                           -0.042563
# Gender_Male                                              0.042563
# JobRole_Healthcare Representative                       -0.045255
# JobRole_Human Resources                                  0.666390
# JobRole_Laboratory Technician                           -0.078278
# JobRole_Manager                                         -0.008572
# JobRole_Manufacturing Director                          -0.049300
# JobRole_Research Director                               -0.014036
# JobRole_Research Scientist                              -0.086749
# JobRole_Sales Executive                                 -0.082274
# JobRole_Sales Representative                            -0.042975
# MaritalStatus_Divorced                                   0.025029
# MaritalStatus_Married                                    0.067980
# MaritalStatus_Single                                    -0.093155
# OverTime_No                                              0.002832
# OverTime_Yes                                            -0.002832
# Age                                                     -0.019798
# Attrition                                                0.057013
# DistanceFromHome                                        -0.022028
# Education                                                0.019196
# EnvironmentSatisfaction                                 -0.028481
# JobInvolvement                                          -0.002684
# JobLevel                                                -0.045716
# JobSatisfaction                                         -0.040511
# MonthlyIncome                                           -0.038060
# NumCompaniesWorked                                       0.036824
# PercentSalaryHike                                       -0.029846
# RelationshipSatisfaction                                 0.066683
# StockOptionLevel                                         0.010915
# TotalWorkingYears                                       -0.019098
# TrainingTimesLastYear                                   -0.007105
# WorkLifeBalance                                         -0.007836
# YearsAtCompany                                          -0.004727
# YearsInCurrentRole                                      -0.016740
# YearsSinceLastPromotion                                  0.016936
# YearsWithCurrManager                                    -0.027181
# AnnualIncome                                            -0.038060
#
#                                    EducationField_Life Sciences  \
# BusinessTravel_Non-Travel                              0.015488
# BusinessTravel_Travel_Frequently                       0.021972
# BusinessTravel_Travel_Rarely                          -0.029338
# Department_Human Resources                            -0.084161
# Department_Research & Development                      0.154203
# Department_Sales                                      -0.120696
# EducationField_Human Resources                        -0.129352
# EducationField_Life Sciences                           1.000000
# EducationField_Marketing                              -0.309944
# EducationField_Medical                                -0.543427
# EducationField_Other                                  -0.211261
# EducationField_Technical Degree                       -0.275030
# Gender_Female                                          0.021485
# Gender_Male                                           -0.021485
# JobRole_Healthcare Representative                      0.066780
# JobRole_Human Resources                               -0.084161
# JobRole_Laboratory Technician                          0.065638
# JobRole_Manager                                       -0.010189
# JobRole_Manufacturing Director                         0.073320
# JobRole_Research Director                              0.014614
# JobRole_Research Scientist                             0.015286
# JobRole_Sales Executive                               -0.099508
# JobRole_Sales Representative                          -0.053819
# MaritalStatus_Divorced                                -0.000647
# MaritalStatus_Married                                 -0.028783
# MaritalStatus_Single                                   0.030771
# OverTime_No                                            0.007201
# OverTime_Yes                                          -0.007201
# Age                                                    0.047809
# Attrition                                             -0.049206
# DistanceFromHome                                       0.003879
# Education                                             -0.024198
# EnvironmentSatisfaction                               -0.037119
# JobInvolvement                                         0.012198
# JobLevel                                               0.015996
# JobSatisfaction                                        0.096549
# MonthlyIncome                                          0.008493
# NumCompaniesWorked                                     0.008742
# PercentSalaryHike                                      0.037833
# RelationshipSatisfaction                              -0.021686
# StockOptionLevel                                      -0.013664
# TotalWorkingYears                                      0.024206
# TrainingTimesLastYear                                 -0.042186
# WorkLifeBalance                                       -0.010883
# YearsAtCompany                                         0.025007
# YearsInCurrentRole                                     0.026884
# YearsSinceLastPromotion                                0.001262
# YearsWithCurrManager                                   0.008798
# AnnualIncome                                           0.008493
#
#                                    EducationField_Marketing  \
# BusinessTravel_Non-Travel                         -0.027114
# BusinessTravel_Travel_Frequently                  -0.024641
# BusinessTravel_Travel_Rarely                       0.039451
# Department_Human Resources                        -0.082344
# Department_Research & Development                 -0.489895
# Department_Sales                                   0.547491
# EducationField_Human Resources                    -0.054873
# EducationField_Life Sciences                      -0.309944
# EducationField_Marketing                           1.000000
# EducationField_Medical                            -0.230531
# EducationField_Other                              -0.089620
# EducationField_Technical Degree                   -0.116672
# Gender_Female                                      0.022082
# Gender_Male                                       -0.022082
# JobRole_Healthcare Representative                 -0.108438
# JobRole_Human Resources                           -0.082344
# JobRole_Laboratory Technician                     -0.187565
# JobRole_Manager                                   -0.020540
# JobRole_Manufacturing Director                    -0.118130
# JobRole_Research Director                         -0.033631
# JobRole_Research Scientist                        -0.207863
# JobRole_Sales Executive                            0.500480
# JobRole_Sales Representative                       0.162868
# MaritalStatus_Divorced                             0.018501
# MaritalStatus_Married                             -0.002284
# MaritalStatus_Single                              -0.013725
# OverTime_No                                       -0.028671
# OverTime_Yes                                       0.028671
# Age                                                0.043865
# Attrition                                          0.039830
# DistanceFromHome                                   0.020338
# Education                                          0.114131
# EnvironmentSatisfaction                            0.035103
# JobInvolvement                                    -0.005772
# JobLevel                                           0.207780
# JobSatisfaction                                   -0.035895
# MonthlyIncome                                      0.190410
# NumCompaniesWorked                                -0.031009
# PercentSalaryHike                                 -0.066374
# RelationshipSatisfaction                           0.012753
# StockOptionLevel                                   0.043594
# TotalWorkingYears                                  0.053748
# TrainingTimesLastYear                              0.025362
# WorkLifeBalance                                    0.004966
# YearsAtCompany                                     0.033621
# YearsInCurrentRole                                 0.034575
# YearsSinceLastPromotion                            0.018296
# YearsWithCurrManager                               0.022529
# AnnualIncome                                       0.190410
#
#                                    EducationField_Medical  \
# BusinessTravel_Non-Travel                       -0.026798
# BusinessTravel_Travel_Frequently                 0.001122
# BusinessTravel_Travel_Rarely                     0.017045
# Department_Human Resources                      -0.057145
# Department_Research & Development                0.189898
# Department_Sales                                -0.170445
# EducationField_Human Resources                  -0.096210
# EducationField_Life Sciences                    -0.543427
# EducationField_Marketing                        -0.230531
# EducationField_Medical                           1.000000
# EducationField_Other                            -0.157132
# EducationField_Technical Degree                 -0.204562
# Gender_Female                                    0.014432
# Gender_Male                                     -0.014432
# JobRole_Healthcare Representative                0.024326
# JobRole_Human Resources                         -0.057145
# JobRole_Laboratory Technician                    0.069278
# JobRole_Manager                                  0.005691
# JobRole_Manufacturing Director                   0.016740
# JobRole_Research Director                        0.043460
# JobRole_Research Scientist                       0.104889
# JobRole_Sales Executive                         -0.149253
# JobRole_Sales Representative                    -0.055099
# MaritalStatus_Divorced                          -0.015529
# MaritalStatus_Married                            0.015432
# MaritalStatus_Single                            -0.002662
# OverTime_No                                     -0.002865
# OverTime_Yes                                     0.002865
# Age                                             -0.042417
# Attrition                                       -0.032477
# DistanceFromHome                                -0.018444
# Education                                       -0.068625
# EnvironmentSatisfaction                         -0.019174
# JobInvolvement                                   0.008776
# JobLevel                                        -0.098768
# JobSatisfaction                                 -0.024435
# MonthlyIncome                                   -0.088326
# NumCompaniesWorked                               0.008503
# PercentSalaryHike                                0.017451
# RelationshipSatisfaction                         0.017743
# StockOptionLevel                                 0.020398
# TotalWorkingYears                               -0.033839
# TrainingTimesLastYear                           -0.008562
# WorkLifeBalance                                 -0.003045
# YearsAtCompany                                  -0.041331
# YearsInCurrentRole                              -0.067149
# YearsSinceLastPromotion                         -0.003596
# YearsWithCurrManager                            -0.026888
# AnnualIncome                                    -0.088326
#
#                                    EducationField_Other  \
# BusinessTravel_Non-Travel                     -0.010418
# BusinessTravel_Travel_Frequently              -0.015836
# BusinessTravel_Travel_Rarely                   0.020644
# Department_Human Resources                     0.007456
# Department_Research & Development              0.048939
# Department_Sales                              -0.054331
# EducationField_Human Resources                -0.037402
# EducationField_Life Sciences                  -0.211261
# EducationField_Marketing                      -0.089620
# EducationField_Medical                        -0.157132
# EducationField_Other                           1.000000
# EducationField_Technical Degree               -0.079525
# Gender_Female                                  0.007502
# Gender_Male                                   -0.007502
# JobRole_Healthcare Representative              0.009457
# JobRole_Human Resources                        0.007456
# JobRole_Laboratory Technician                  0.085255
# JobRole_Manager                               -0.014000
# JobRole_Manufacturing Director                -0.002816
# JobRole_Research Director                     -0.022923
# JobRole_Research Scientist                    -0.024993
# JobRole_Sales Executive                       -0.036209
# JobRole_Sales Representative                  -0.035354
# MaritalStatus_Divorced                         0.025028
# MaritalStatus_Married                         -0.008741
# MaritalStatus_Single                          -0.012637
# OverTime_No                                   -0.011157
# OverTime_Yes                                   0.011157
# Age                                           -0.041925
# Attrition                                     -0.024375
# DistanceFromHome                              -0.016957
# Education                                      0.031352
# EnvironmentSatisfaction                        0.073906
# JobInvolvement                                -0.052421
# JobLevel                                      -0.013562
# JobSatisfaction                               -0.066756
# MonthlyIncome                                 -0.023641
# NumCompaniesWorked                            -0.024359
# PercentSalaryHike                              0.008321
# RelationshipSatisfaction                      -0.015126
# StockOptionLevel                              -0.041407
# TotalWorkingYears                             -0.023097
# TrainingTimesLastYear                          0.046470
# WorkLifeBalance                                0.015330
# YearsAtCompany                                -0.014740
# YearsInCurrentRole                             0.005591
# YearsSinceLastPromotion                       -0.046031
# YearsWithCurrManager                           0.016443
# AnnualIncome                                  -0.023641
#
#                                    EducationField_Technical Degree  \
# BusinessTravel_Non-Travel                                 0.056075
# BusinessTravel_Travel_Frequently                         -0.017521
# BusinessTravel_Travel_Rarely                             -0.022597
# Department_Human Resources                               -0.022274
# Department_Research & Development                         0.047002
# Department_Sales                                         -0.038374
# EducationField_Human Resources                           -0.048692
# EducationField_Life Sciences                             -0.275030
# EducationField_Marketing                                 -0.116672
# EducationField_Medical                                   -0.204562
# EducationField_Other                                     -0.079525
# EducationField_Technical Degree                           1.000000
# Gender_Female                                            -0.067470
# Gender_Male                                               0.067470
# JobRole_Healthcare Representative                        -0.016302
# JobRole_Human Resources                                  -0.022274
# JobRole_Laboratory Technician                            -0.040998
# JobRole_Manager                                           0.046531
# JobRole_Manufacturing Director                            0.006909
# JobRole_Research Director                                -0.029843
# JobRole_Research Scientist                                0.103680
# JobRole_Sales Executive                                  -0.079087
# JobRole_Sales Representative                              0.047764
# MaritalStatus_Divorced                                   -0.027818
# MaritalStatus_Married                                    -0.000204
# MaritalStatus_Single                                      0.024457
# OverTime_No                                               0.031239
# OverTime_Yes                                             -0.031239
# Age                                                      -0.019794
# Attrition                                                 0.080550
# DistanceFromHome                                          0.024440
# Education                                                -0.012675
# EnvironmentSatisfaction                                   0.009479
# JobInvolvement                                            0.015292
# JobLevel                                                 -0.068071
# JobSatisfaction                                          -0.012269
# MonthlyIncome                                            -0.048315
# NumCompaniesWorked                                        0.006845
# PercentSalaryHike                                        -0.009737
# RelationshipSatisfaction                                 -0.026584
# StockOptionLevel                                         -0.028904
# TotalWorkingYears                                        -0.019391
# TrainingTimesLastYear                                     0.023361
# WorkLifeBalance                                           0.009434
# YearsAtCompany                                           -0.000959
# YearsInCurrentRole                                        0.024755
# YearsSinceLastPromotion                                   0.011516
# YearsWithCurrManager                                      0.002743
# AnnualIncome                                             -0.048315
#
#                                    Gender_Female  Gender_Male  \
# BusinessTravel_Non-Travel              -0.072031     0.072031
# BusinessTravel_Travel_Frequently        0.020386    -0.020386
# BusinessTravel_Travel_Rarely            0.030853    -0.030853
# Department_Human Resources             -0.012377     0.012377
# Department_Research & Development      -0.035776     0.035776
# Department_Sales                        0.042967    -0.042967
# EducationField_Human Resources         -0.042563     0.042563
# EducationField_Life Sciences            0.021485    -0.021485
# EducationField_Marketing                0.022082    -0.022082
# EducationField_Medical                  0.014432    -0.014432
# EducationField_Other                    0.007502    -0.007502
# EducationField_Technical Degree        -0.067470     0.067470
# Gender_Female                           1.000000    -1.000000
# Gender_Male                            -1.000000     1.000000
# JobRole_Healthcare Representative      -0.006528     0.006528
# JobRole_Human Resources                -0.012377     0.012377
# JobRole_Laboratory Technician          -0.086873     0.086873
# JobRole_Manager                        -0.004784     0.004784
# JobRole_Manufacturing Director          0.047289    -0.047289
# JobRole_Research Director               0.048068    -0.048068
# JobRole_Research Scientist              0.000947    -0.000947
# JobRole_Sales Executive                 0.036335    -0.036335
# JobRole_Sales Representative            0.023524    -0.023524
# MaritalStatus_Divorced                 -0.081904     0.081904
# MaritalStatus_Married                   0.023648    -0.023648
# MaritalStatus_Single                    0.046559    -0.046559
# OverTime_No                            -0.056663     0.056663
# OverTime_Yes                            0.056663    -0.056663
# Age                                     0.034742    -0.034742
# Attrition                              -0.019709     0.019709
# DistanceFromHome                       -0.031964     0.031964
# Education                               0.020740    -0.020740
# EnvironmentSatisfaction                -0.007980     0.007980
# JobInvolvement                         -0.003679     0.003679
# JobLevel                                0.047224    -0.047224
# JobSatisfaction                        -0.028123     0.028123
# MonthlyIncome                           0.019047    -0.019047
# NumCompaniesWorked                      0.065269    -0.065269
# PercentSalaryHike                      -0.001083     0.001083
# RelationshipSatisfaction               -0.015727     0.015727
# StockOptionLevel                       -0.019653     0.019653
# TotalWorkingYears                       0.038516    -0.038516
# TrainingTimesLastYear                   0.050001    -0.050001
# WorkLifeBalance                         0.025034    -0.025034
# YearsAtCompany                          0.033459    -0.033459
# YearsInCurrentRole                      0.024426    -0.024426
# YearsSinceLastPromotion                 0.017110    -0.017110
# YearsWithCurrManager                    0.022163    -0.022163
# AnnualIncome                            0.019047    -0.019047
#
#                                    JobRole_Healthcare Representative  \
# BusinessTravel_Non-Travel                                   0.023677
# BusinessTravel_Travel_Frequently                           -0.007654
# BusinessTravel_Travel_Rarely                               -0.009320
# Department_Human Resources                                 -0.067911
# Department_Research & Development                           0.221348
# Department_Sales                                           -0.198063
# EducationField_Human Resources                             -0.045255
# EducationField_Life Sciences                                0.066780
# EducationField_Marketing                                   -0.108438
# EducationField_Medical                                      0.024326
# EducationField_Other                                        0.009457
# EducationField_Technical Degree                            -0.016302
# Gender_Female                                              -0.006528
# Gender_Male                                                 0.006528
# JobRole_Healthcare Representative                           1.000000
# JobRole_Human Resources                                    -0.067911
# JobRole_Laboratory Technician                              -0.154689
# JobRole_Manager                                            -0.016939
# JobRole_Manufacturing Director                             -0.097424
# JobRole_Research Director                                  -0.027736
# JobRole_Research Scientist                                 -0.171429
# JobRole_Sales Executive                                    -0.162585
# JobRole_Sales Representative                               -0.084924
# MaritalStatus_Divorced                                      0.049461
# MaritalStatus_Married                                      -0.008984
# MaritalStatus_Single                                       -0.033675
# OverTime_No                                                 0.031165
# OverTime_Yes                                               -0.031165
# Age                                                         0.132710
# Attrition                                                  -0.083402
# DistanceFromHome                                            0.040639
# Education                                                   0.007632
# EnvironmentSatisfaction                                     0.017262
# JobInvolvement                                              0.021615
# JobLevel                                                    0.278448
# JobSatisfaction                                             0.000920
# MonthlyIncome                                               0.266718
# NumCompaniesWorked                                          0.038793
# PercentSalaryHike                                           0.003308
# RelationshipSatisfaction                                    0.003594
# StockOptionLevel                                           -0.022967
# TotalWorkingYears                                           0.205214
# TrainingTimesLastYear                                      -0.067221
# WorkLifeBalance                                            -0.020874
# YearsAtCompany                                              0.093194
# YearsInCurrentRole                                          0.056117
# YearsSinceLastPromotion                                     0.029329
# YearsWithCurrManager                                        0.062663
# AnnualIncome                                                0.266718
#
#                                    JobRole_Human Resources  \
# BusinessTravel_Non-Travel                        -0.013738
# BusinessTravel_Travel_Frequently                  0.002165
# BusinessTravel_Travel_Rarely                      0.007368
# Department_Human Resources                        1.000000
# Department_Research & Development                -0.306806
# Department_Sales                                 -0.150403
# EducationField_Human Resources                    0.666390
# EducationField_Life Sciences                     -0.084161
# EducationField_Marketing                         -0.082344
# EducationField_Medical                           -0.057145
# EducationField_Other                              0.007456
# EducationField_Technical Degree                  -0.022274
# Gender_Female                                    -0.012377
# Gender_Male                                       0.012377
# JobRole_Healthcare Representative                -0.067911
# JobRole_Human Resources                           1.000000
# JobRole_Laboratory Technician                    -0.117466
# JobRole_Manager                                  -0.012863
# JobRole_Manufacturing Director                   -0.073981
# JobRole_Research Director                        -0.021062
# JobRole_Research Scientist                       -0.130178
# JobRole_Sales Executive                          -0.123462
# JobRole_Sales Representative                     -0.064489
# MaritalStatus_Divorced                            0.023883
# MaritalStatus_Married                             0.045702
# MaritalStatus_Single                             -0.068776
# OverTime_No                                       0.016631
# OverTime_Yes                                     -0.016631
# Age                                              -0.000188
# Attrition                                         0.030641
# DistanceFromHome                                 -0.025809
# ...
# Gender_Female                               0.038516               0.050001
# Gender_Male                                -0.038516              -0.050001
# JobRole_Healthcare Representative           0.205214              -0.067221
# JobRole_Human Resources                    -0.025749              -0.008052
# JobRole_Laboratory Technician              -0.129485               0.046983
# JobRole_Manager                             0.035035              -0.026617
# JobRole_Manufacturing Director              0.142531              -0.044575
# JobRole_Research Director                   0.074994               0.046519
# JobRole_Research Scientist                 -0.114516              -0.041676
# JobRole_Sales Executive                     0.151960               0.020947
# JobRole_Sales Representative               -0.240276               0.078250
# MaritalStatus_Divorced                      0.054954              -0.032539
# MaritalStatus_Married                       0.021712              -0.004928
# MaritalStatus_Single                       -0.070677               0.033529
# OverTime_No                                 0.009186              -0.013469
# OverTime_Yes                               -0.009186               0.013469
# Age                                         0.519703               0.043746
# Attrition                                  -0.206670              -0.006281
# DistanceFromHome                            0.045074              -0.026157
# Education                                   0.184877               0.029593
# EnvironmentSatisfaction                    -0.027430               0.017898
# JobInvolvement                              0.019911               0.002215
# JobLevel                                    0.526005              -0.013759
# JobSatisfaction                            -0.017531              -0.047618
# MonthlyIncome                               0.497600              -0.043121
# NumCompaniesWorked                          0.306875              -0.000230
# PercentSalaryHike                           0.013451               0.018321
# RelationshipSatisfaction                   -0.017816               0.012517
# StockOptionLevel                            0.055612               0.021290
# TotalWorkingYears                           1.000000               0.032774
# TrainingTimesLastYear                       0.032774               1.000000
# WorkLifeBalance                             0.009165               0.046999
# YearsAtCompany                              0.495345               0.019906
# YearsInCurrentRole                          0.427591               0.018357
# YearsSinceLastPromotion                     0.201645               0.020602
# YearsWithCurrManager                        0.439762               0.003922
# AnnualIncome                                0.497600              -0.043121
#
#                                    WorkLifeBalance  YearsAtCompany  \
# BusinessTravel_Non-Travel                 0.026923        0.035719
# BusinessTravel_Travel_Frequently          0.025216        0.023824
# BusinessTravel_Travel_Rarely             -0.039818       -0.044532
# Department_Human Resources                0.037174       -0.010572
# Department_Research & Development        -0.066419       -0.044423
# Department_Sales                          0.051553        0.051103
# EducationField_Human Resources           -0.007836       -0.004727
# EducationField_Life Sciences             -0.010883        0.025007
# EducationField_Marketing                  0.004966        0.033621
# EducationField_Medical                   -0.003045       -0.041331
# EducationField_Other                      0.015330       -0.014740
# EducationField_Technical Degree           0.009434       -0.000959
# Gender_Female                             0.025034        0.033459
# Gender_Male                              -0.025034       -0.033459
# JobRole_Healthcare Representative        -0.020874        0.093194
# JobRole_Human Resources                   0.037174       -0.010572
# JobRole_Laboratory Technician            -0.010211       -0.112201
# JobRole_Manager                          -0.059078        0.027968
# JobRole_Manufacturing Director            0.011835        0.102042
# JobRole_Research Director                 0.015882        0.155670
# JobRole_Research Scientist               -0.062990       -0.108131
# JobRole_Sales Executive                   0.032285        0.172864
# JobRole_Sales Representative              0.052851       -0.187775
# MaritalStatus_Divorced                    0.006002        0.000133
# MaritalStatus_Married                     0.006953        0.042109
# MaritalStatus_Single                     -0.012527       -0.044308
# OverTime_No                               0.050128        0.050423
# OverTime_Yes                             -0.050128       -0.050423
# Age                                      -0.007228        0.113158
# Attrition                                -0.062773       -0.226950
# DistanceFromHome                         -0.044153        0.021656
# Education                                 0.041402        0.075930
# EnvironmentSatisfaction                   0.008006        0.019007
# JobInvolvement                            0.000840        0.036442
# JobLevel                                  0.032458        0.408271
# JobSatisfaction                          -0.035318        0.054643
# MonthlyIncome                             0.016142        0.380003
# NumCompaniesWorked                        0.012347       -0.151128
# PercentSalaryHike                        -0.044894       -0.009198
# RelationshipSatisfaction                  0.044393       -0.013002
# StockOptionLevel                          0.035726        0.046184
# TotalWorkingYears                         0.009165        0.495345
# TrainingTimesLastYear                     0.046999        0.019906
# WorkLifeBalance                           1.000000        0.023951
# YearsAtCompany                            0.023951        1.000000
# YearsInCurrentRole                        0.031353        0.857825
# YearsSinceLastPromotion                   0.042058        0.395451
# YearsWithCurrManager                      0.037764        0.846897
# AnnualIncome                              0.016142        0.380003
#
#                                    YearsInCurrentRole  \
# BusinessTravel_Non-Travel                    0.052671
# BusinessTravel_Travel_Frequently             0.028066
# BusinessTravel_Travel_Rarely                -0.059579
# Department_Human Resources                  -0.033424
# Department_Research & Development           -0.048972
# Department_Sales                             0.066547
# EducationField_Human Resources              -0.016740
# EducationField_Life Sciences                 0.026884
# EducationField_Marketing                     0.034575
# EducationField_Medical                      -0.067149
# EducationField_Other                         0.005591
# EducationField_Technical Degree              0.024755
# Gender_Female                                0.024426
# Gender_Male                                 -0.024426
# JobRole_Healthcare Representative            0.056117
# JobRole_Human Resources                     -0.033424
# JobRole_Laboratory Technician               -0.096116
# JobRole_Manager                             -0.005322
# JobRole_Manufacturing Director               0.097255
# JobRole_Research Director                    0.121038
# JobRole_Research Scientist                  -0.089295
# JobRole_Sales Executive                      0.158611
# JobRole_Sales Representative                -0.138774
# MaritalStatus_Divorced                       0.004695
# MaritalStatus_Married                        0.028699
# MaritalStatus_Single                        -0.034211
# OverTime_No                                  0.041851
# OverTime_Yes                                -0.041851
# Age                                          0.095494
# Attrition                                   -0.204840
# DistanceFromHome                             0.027669
# Education                                    0.083922
# EnvironmentSatisfaction                      0.035613
# JobInvolvement                               0.014357
# JobLevel                                     0.358830
# JobSatisfaction                              0.033321
# MonthlyIncome                                0.335616
# NumCompaniesWorked                          -0.111169
# PercentSalaryHike                           -0.001009
# RelationshipSatisfaction                    -0.023462
# StockOptionLevel                             0.042694
# TotalWorkingYears                            0.427591
# TrainingTimesLastYear                        0.018357
# WorkLifeBalance                              0.031353
# YearsAtCompany                               0.857825
# YearsInCurrentRole                           1.000000
# YearsSinceLastPromotion                      0.416740
# YearsWithCurrManager                         0.739570
# AnnualIncome                                 0.335616
#
#                                    YearsSinceLastPromotion  \
# BusinessTravel_Non-Travel                         0.003974
# BusinessTravel_Travel_Frequently                  0.013113
# BusinessTravel_Travel_Rarely                     -0.013967
# Department_Human Resources                        0.035750
# Department_Research & Development                -0.010453
# Department_Sales                                 -0.005912
# EducationField_Human Resources                    0.016936
# EducationField_Life Sciences                      0.001262
# EducationField_Marketing                          0.018296
# EducationField_Medical                           -0.003596
# EducationField_Other                             -0.046031
# EducationField_Technical Degree                   0.011516
# Gender_Female                                     0.017110
# Gender_Male                                      -0.017110
# JobRole_Healthcare Representative                 0.029329
# JobRole_Human Resources                           0.035750
# JobRole_Laboratory Technician                    -0.039956
# JobRole_Manager                                  -0.043249
# JobRole_Manufacturing Director                    0.040593
# JobRole_Research Director                         0.086722
# JobRole_Research Scientist                       -0.036759
# JobRole_Sales Executive                           0.007274
# JobRole_Sales Representative                     -0.015778
# MaritalStatus_Divorced                           -0.038970
# MaritalStatus_Married                             0.059395
# MaritalStatus_Single                             -0.028373
# OverTime_No                                       0.008680
# OverTime_Yes                                     -0.008680
# Age                                               0.059865
# Attrition                                        -0.079108
# DistanceFromHome                                 -0.015766
# Education                                         0.015406
# EnvironmentSatisfaction                           0.044996
# JobInvolvement                                   -0.007634
# JobLevel                                          0.105858
# JobSatisfaction                                   0.044342
# MonthlyIncome                                     0.109425
# NumCompaniesWorked                               -0.034462
# PercentSalaryHike                                 0.005628
# RelationshipSatisfaction                          0.030753
# StockOptionLevel                                  0.010122
# TotalWorkingYears                                 0.201645
# TrainingTimesLastYear                             0.020602
# WorkLifeBalance                                   0.042058
# YearsAtCompany                                    0.395451
# YearsInCurrentRole                                0.416740
# YearsSinceLastPromotion                           1.000000
# YearsWithCurrManager                              0.349210
# AnnualIncome                                      0.109425
#
#                                    YearsWithCurrManager  AnnualIncome
# BusinessTravel_Non-Travel                      0.054813      0.007317
# BusinessTravel_Travel_Frequently               0.005274     -0.021922
# BusinessTravel_Travel_Rarely                  -0.041385      0.013967
# Department_Human Resources                    -0.014311     -0.061050
# Department_Research & Development             -0.036015     -0.203020
# Department_Sales                               0.044123      0.239519
# EducationField_Human Resources                -0.027181     -0.038060
# EducationField_Life Sciences                   0.008798      0.008493
# EducationField_Marketing                       0.022529      0.190410
# EducationField_Medical                        -0.026888     -0.088326
# EducationField_Other                           0.016443     -0.023641
# EducationField_Technical Degree                0.002743     -0.048315
# Gender_Female                                  0.022163      0.019047
# Gender_Male                                   -0.022163     -0.019047
# JobRole_Healthcare Representative              0.062663      0.266718
# JobRole_Human Resources                       -0.014311     -0.061050
# JobRole_Laboratory Technician                 -0.095651     -0.309006
# JobRole_Manager                                0.022848      0.173683
# JobRole_Manufacturing Director                 0.117478      0.266236
# JobRole_Research Director                      0.164474      0.278977
# JobRole_Research Scientist                    -0.108726     -0.351337
# JobRole_Sales Executive                        0.155017      0.400145
# JobRole_Sales Representative                  -0.168314     -0.244038
# MaritalStatus_Divorced                        -0.005202      0.015645
# MaritalStatus_Married                          0.014299      0.021930
# MaritalStatus_Single                          -0.010473     -0.036649
# OverTime_No                                    0.069333     -0.006292
# OverTime_Yes                                  -0.069333      0.006292
# Age                                            0.097699      0.237086
# Attrition                                     -0.200570     -0.159990
# DistanceFromHome                               0.010063      0.059777
# Education                                      0.046545      0.113193
# EnvironmentSatisfaction                        0.005386     -0.009230
# JobInvolvement                                 0.049172     -0.025667
# JobLevel                                       0.368542      0.866081
# JobSatisfaction                                0.022873     -0.001988
# MonthlyIncome                                  0.341767      1.000000
# NumCompaniesWorked                            -0.105262      0.115638
# PercentSalaryHike                              0.008995     -0.019945
# RelationshipSatisfaction                       0.007345      0.000198
# StockOptionLevel                               0.030692      0.028550
# TotalWorkingYears                              0.439762      0.497600
# TrainingTimesLastYear                          0.003922     -0.043121
# WorkLifeBalance                                0.037764      0.016142
# YearsAtCompany                                 0.846897      0.380003
# YearsInCurrentRole                             0.739570      0.335616
# YearsSinceLastPromotion                        0.349210      0.109425
# YearsWithCurrManager                           1.000000      0.341767
# AnnualIncome                                   0.341767      1.000000

# %%
df.head()
# Out:
#    Age  Attrition     BusinessTravel              Department  \
# 0   41          1      Travel_Rarely                   Sales
# 1   49          0  Travel_Frequently  Research & Development
# 2   37          1      Travel_Rarely  Research & Development
# 3   33          0  Travel_Frequently  Research & Development
# 4   27          0      Travel_Rarely  Research & Development
#
#    DistanceFromHome  Education EducationField  EnvironmentSatisfaction  \
# 0                 1          2  Life Sciences                        2
# 1                 8          1  Life Sciences                        3
# 2                 2          2          Other                        4
# 3                 3          4  Life Sciences                        4
# 4                 2          1        Medical                        1
#
#    Gender  JobInvolvement  JobLevel                JobRole  JobSatisfaction  \
# 0  Female               3         2        Sales Executive                4
# 1    Male               2         2     Research Scientist                2
# 2    Male               2         1  Laboratory Technician                3
# 3  Female               3         1     Research Scientist                3
# 4    Male               3         1  Laboratory Technician                2
#
#   MaritalStatus  MonthlyIncome  NumCompaniesWorked OverTime  \
# 0        Single           5993                   8      Yes
# 1       Married           5130                   1       No
# 2        Single           2090                   6      Yes
# 3       Married           2909                   1      Yes
# 4       Married           3468                   9       No
#
#    PercentSalaryHike  RelationshipSatisfaction  StockOptionLevel  \
# 0                 11                         1                 0
# 1                 23                         4                 1
# 2                 15                         2                 0
# 3                 11                         3                 0
# 4                 12                         4                 1
#
#    TotalWorkingYears  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# 0                  8                      0                1               6
# 1                 10                      3                3              10
# 2                  7                      3                3               0
# 3                  8                      3                3               8
# 4                  6                      3                3               2
#
#    YearsInCurrentRole  YearsSinceLastPromotion  YearsWithCurrManager  \
# 0                   4                        0                     5
# 1                   7                        1                     7
# 2                   0                        0                     0
# 3                   7                        3                     0
# 4                   2                        2                     2
#
#    AnnualIncome
# 0         71916
# 1         61560
# 2         25080
# 3         34908
# 4         41616

# %%
df['Attrition'].value_counts()
# Out:
# 0    763
# 1    175
# Name: Attrition, dtype: int64

# %%
list(df.columns)
# Out:
# ['Age',
#  'Attrition',
#  'BusinessTravel',
#  'Department',
#  'DistanceFromHome',
#  'Education',
#  'EducationField',
#  'EnvironmentSatisfaction',
#  'Gender',
#  'JobInvolvement',
#  'JobLevel',
#  'JobRole',
#  'JobSatisfaction',
#  'MaritalStatus',
#  'MonthlyIncome',
#  'NumCompaniesWorked',
#  'OverTime',
#  'PercentSalaryHike',
#  'RelationshipSatisfaction',
#  'StockOptionLevel',
#  'TotalWorkingYears',
#  'TrainingTimesLastYear',
#  'WorkLifeBalance',
#  'YearsAtCompany',
#  'YearsInCurrentRole',
#  'YearsSinceLastPromotion',
#  'YearsWithCurrManager',
#  'AnnualIncome']

# %%
df['MonthlyIncome'].unique()
# Out:
# array([ 5993,  5130,  2090,  2909,  3468,  3068,  2670,  2693,  9526,
#         4193,  2911,  2661,  2028,  2935,  3944,  3407, 11994,  2960,
#         6825,  2496,  2293,  2645,  2683,  2014,  3419,  5376,  1951,
#         8726,  4011,  3022,  5772,  2269,  3441,  5454,  9884,  4157,
#         9069,  4014,  5915,  6499,  2194,  3388,  5473,  2703,  2501,
#         6220,  3038,  4424,  4312,  5021,  5126,  2859,  5329,  4325,
#         2322,  2075,  9619,  5441,  5209,  5010,  4999,  4221,  2042,
#         2073,  2956,  4809,  5163,  5744,  2889,  6074,  2774,  4505,
#         7428,  2835,  2613,  6146,  4963,  2368,  1675,  2523,  6567,
#         4739,  9208,  4559,  8189,  2942,  4941, 10650,  5902,  8639,
#         6347,  4200,  3452,  4317,  2632,  4668,  3204,  2720,  2238,
#         1483,  7295,  2306,  8998,  4319,  6132,  3346, 10855,  2231,
#         2024,  2713,  9439,  2566,  2451,  8686,  3058,  5006,  4257,
#         2500,  1102,  2288,  3929,  2311,  3690,  4450,  9547,  2279,
#         5916,  2089,  3564,  6553,  6261,  4298,  6804,  3815,  2741,
#         6673,  7639,  2328,  2153,  9396,  8474,  9981,  2058,  5940,
#         5914,  2622,  4345,  2793,  8789,  2389,  3212,  2267,  2436,
#         2707,  3730,  2232,  4465,  3072,  3319,  5957,  3920,  6434,
#         2340,  6545,  6931,  4898,  2723,  3479,  2794,  6644,  4000,
#         2070,  3230,  4554,  5415,  4741,  3161,  5745,  2373,  3310,
#         2326,  1420,  3688,  5482,  1200,  5661,  5674,  5484,  5660,
#         4821,  6410,  2695,  2478,  4478,  7547,  5055,  3464,  5775,
#         5238,  5257,  6349,  4869,  9985,  7457,  2119,  3983,  6118,
#         6214, 11510,  7143,  8268,  2904,  6032,  2976,  4649,  2370,
#         4736,  2174,  9699,  6755,  2213,  2610,  2851,  5258, 10496,
#         2716,  2201,  3816,  5253,  4936,  2543,  5304,  4260,  2476,
#         3102,  2244,  2285,  4197,  3448,  6538,  2258,  4522,  4487,
#         2218,  8392,  4558,  2654,  4556,  6091,  4523,  3202,  2351,
#         1702,  2886,  2097, 11935,  2546,  2564,  5070,  4230,  3780,
#         2768,  9071,  3408,  2983,  7632,  9824,  9950,  2093,  3894,
#         6230,  3755,  6582,  4805,  4262, 11557,  1878, 10932,  6811,
#         4859,  5337,  7491,  4707,  2400,  6447,  2725,  2127,  2096,
#         2033,  3622,  4233,  3681,  5460,  9602,  2836,  4089,  2619,
#         5679,  5985,  2579,  3041,  3447,  2773,  7104,  6322,  2083,
#         4286,  2659,  7725,  8847,  2045,  1281,  2819,  4851,  4028,
#         8120,  4647,  4680,  4577,  5396,  6796,  7625,  7412,  4960,
#         5405,  8793,  3875,  2216, 11713,  7861,  2759,  6142,  6389,
#         2342,  2297,  2450,  5093,  5309,  3057,  5121,  6632,  3505,
#         6397,  7587,  4258,  4364,  4335,  5326,  3280,  5485,  4342,
#         2782,  5980,  4381,  2572,  3833,  4244,  6500,  1601,  2694,
#         3149,  2319, 11691,  5324,  5228,  2700,  2506,  6062,  4382,
#         2143,  6877,  2274,  6288,  2553, 10221,  3737,  2366,  5933,
#         3424,  2559,  4403,  3761, 10761,  5175,  6334,  4775,  2818,
#         2515,  4194,  2314,  4256,  3580,  3162,  6524,  2899,  5231,
#         2356,  2800, 10903,  2973,  5562,  7642,  5204,  2277,  2795,
#         4908,  2380,  4765,  2044,  6586,  3294,  4171,  2778,  2377,
#         2404,  2318,  2008,  2799,  2329,  2259,  6932,  2332,  2413,
#         9705,  4294,  2121,  3617,  6949,  4601,  2479,  5666,  7823,
#         7880,  5079,  2321,  2270,  5488,  2811,  3633,  4163,  2132,
#         2684, 10845,  3743,  4148,  1051, 11416,  2600,  2422,  5472,
#         4240,  4227,  3917,  4777,  6861,  9725, 11904,  2177,  4834,
#         2220,  2821,  4107,  2323,  4615,  2461,  8722,  3955,  9957,
#         3376,  4621,  3660,  7119,  9582,  4508,  7756,  3691,  2313,
#         2596,  4728,  4302,  2979,  5593, 10445,  8740,  2514,  7655,
#         7351, 10820,  6782,  7779,  2791,  3201,  4968,  4033,  3291,
#         4272,  5056,  2844,  1904,  8224,  4766,  5731,  2539,  5714,
#         4323,  7336,  5155,  3597,  4420,  6578,  4422,  5343,  2376,
#         5346,  2827,  2552,  4477,  6474,  3033,  2936,  2168,  2290,
#         3600,  2107,  4115,  4327,  3196,  8966,  2210,  4539,  2678,
#         7379,  6272,  5220,  2743,  4998,  6852,  4950,  3579,  1859,
#         6833,  6812,  5171,  3692,  2517,  6623,  8380,  2994,  1223,
#         1118,  2875,  2625,  4538,  4444,  2154,  3506,  2372,  5410,
#         7978,  3867,  4695,  2080,  6209,  4883,  3904,  7094,  3423,
#         9094, 11916,  2302,  2362,  3544,  8500,  4103,  4249,  6893,
#         2387,  7898,  2534,  5363,  5071,  2029,  2785,  4614,  6687,
#         4724,  6120,  5467,  2996,  9998,  4078, 10920,  6232,  5769,
#         2950,  9362,  3229,  3578,  7988,  4284,  9278,  1359,  4779,
#         1261,  2099,  5810,  5647,  3420,  4400,  3500,  2066,  4162,
#         9204,  3975,  3646,  7446,  2109,  3722,  9380,  5486,  2742,
#         8463,  6651,  2345,  4373,  4759,  5301,  3673,  4768,  1274,
#         4900,  5765,  3172, 10209,  8620,  2064,  4035,  4591,  2561,
#         1563,  4789,  3180,  6549,  8376,  8606,  2272,  2018,  2308,
#         4841,  4285,  9715,  4320,  5207,  2296,  4069,  5878,  2644,
#         6077,  9250,  2074,  4855,  4087,  2972,  4723,  8853,  4639,
#         4876,  2408,  2814,  3312,  2141,  4385,  5332,  4663,  3211,
#         4066,  3117,  1569,  3069,  5768,  5042,  5770,  7945,  5743,
#         5440,  3760,  3517,  2580,  2166,  5869,  5295,  2783,  2013,
#         6842,  4735,  4187,  5470,  5476,  2587,  2440,  2728,  5368,
#         5347,  3195,  3989,  7005,  1393,  3537,  3986, 10883,  9525,
#         2275,  4930,  4401,  2974,  1555,  2305,  3433,  3477,  6430,
#         6516,  3907,  6883,  2862,  4978,  6134,  6735,  3295,  6472,
#         9610,  9756,  2145,  2180,  8346,  2760,  7140,  2932,  5147,
#         4507,  8564,  2468,  8161,  5294,  2718,  5811,  2437,  3055,
#         2289,  4001,  6029,  2679,  3702,  5468,  4189,  8321,  4071,
#         7991,  5538,  2592,  4213,  2438,  6870,  9667,  2148,  8926,
#         6513,  2705,  6854,  9637,  3591,  4684,  1514,  2335,  5154,
#         6962,  2379,  3812,  4648,  2105,  8578,  2706,  6384,  3968,
#         9907,  2804,  2439,  7314,  3902,  2662,  2856,  1081,  2472,
#         5673,  9713,  2062,  4788,  5906,  3886,  2933,  2307,  5507,
#         4393,  6583,  8103,  3978,  5399,  5487,  6834,  1091,  5736,
#         2226,  9854,  5380,  2432,  4771,  5087,  2863,  5561,  2144,
#         3065,  2810,  9888,  8628,  2367,  2858,  9679,  5617, 10448,
#         5968,  7510,  2991,  1129, 11031,  4440,  4617,  5677,  2187,
#         3977,  3067, 11957,  2660,  3375,  2837,  2406,  4108, 10422,
#         4907,  3482,  1790,  7644,  5131,  6306,  4787,  6712,  8837,
#         6728,  6652,  4850,  2809,  5689,  2001,  4025,  3785, 10854,
#         9936,  2966,  2571,  5390,  4404])

# %%
df['Age'].value_counts()
# Out:
# 34    59
# 35    54
# 29    53
# 31    52
# 32    48
# 36    47
# 30    45
# 38    44
# 33    40
# 28    39
# 27    37
# 37    34
# 40    30
# 26    28
# 24    24
# 45    24
# 25    22
# 42    21
# 39    21
# 41    20
# 44    17
# 43    16
# 46    15
# 23    13
# 47    12
# 22    12
# 49    11
# 50     9
# 21     9
# 20     9
# 51     8
# 19     8
# 18     7
# 56     7
# 48     6
# 52     6
# 54     6
# 59     5
# 53     5
# 58     5
# 55     4
# 57     3
# 60     3
# Name: Age, dtype: int64

# %%
df['MaritalStatus'].value_counts()
# Out:
# Married     416
# Single      318
# Divorced    204
# Name: MaritalStatus, dtype: int64

# %%
sns.countplot(x='MaritalStatus', data=df)
plt.xlabel('Marital Status', fontsize=15);

# %%
df['Gender'].value_counts()
# Out:
# Male      587
# Female    351
# Name: Gender, dtype: int64

# %%
ax = sns.countplot(x='Gender', data=df)
plt.xlabel('Gender', fontsize=15);

# %%
sns.countplot(x='JobRole', data=df)
plt.xticks(rotation=60, ha = 'right')
plt.xlabel('Job Role', fontsize=15);

# %%
sns.countplot(x='JobSatisfaction', data=df)

plt.xlabel('Job Satisfaction', fontsize=15);

# %%
df['JobRole'].value_counts()
# Out:
# Research Scientist           232
# Sales Executive              214
# Laboratory Technician        198
# Manufacturing Director        90
# Healthcare Representative     77
# Sales Representative          70
# Human Resources               46
# Research Director              8
# Manager                        3
# Name: JobRole, dtype: int64

# %% [markdown]
# ## Pickle DF

# %%
#saving pickle for next notebook
we_can_pickle_that = df

# %%
we_can_pickle_that.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 938 entries, 0 to 1469
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       938 non-null    int64
#  1   Attrition                 938 non-null    int64
#  2   BusinessTravel            938 non-null    object
#  3   Department                938 non-null    object
#  4   DistanceFromHome          938 non-null    int64
#  5   Education                 938 non-null    int64
#  6   EducationField            938 non-null    object
#  7   EnvironmentSatisfaction   938 non-null    int64
#  8   Gender                    938 non-null    object
#  9   JobInvolvement            938 non-null    int64
#  10  JobLevel                  938 non-null    int64
#  11  JobRole                   938 non-null    object
#  12  JobSatisfaction           938 non-null    int64
#  13  MaritalStatus             938 non-null    object
#  14  MonthlyIncome             938 non-null    int64
#  15  NumCompaniesWorked        938 non-null    int64
#  16  OverTime                  938 non-null    object
#  17  PercentSalaryHike         938 non-null    int64
#  18  RelationshipSatisfaction  938 non-null    int64
#  19  StockOptionLevel          938 non-null    int64
#  20  TotalWorkingYears         938 non-null    int64
#  21  TrainingTimesLastYear     938 non-null    int64
#  22  WorkLifeBalance           938 non-null    int64
#  23  YearsAtCompany            938 non-null    int64
#  24  YearsInCurrentRole        938 non-null    int64
#  25  YearsSinceLastPromotion   938 non-null    int64
#  26  YearsWithCurrManager      938 non-null    int64
#  27  AnnualIncome              938 non-null    int64
# dtypes: int64(21), object(7)
# memory usage: 252.5+ KB

# %%
we_can_pickle_that.to_pickle('./df.pkl')

# %% [markdown]
# data wrangle - data definitions
#
# eda and descriptive stats end of phase 1 beg of phase 2
#
# in eda- take some of hgc graphs notebook- pie charts and distributions, etc
#
# preprocessing and transform pipeline and could save pickle object
#
# modeling discussion
